# %% [markdown]
# # Markov Chain Reward Function

# %%
import numpy as np
import scipy.linalg
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('G:/UnderGraduate_Project\ibler and mcs2.csv')

state = {
        0:"eMBB User 1",
        1:"eMBB User 2",
        2:"eMBB User 3",
        3:"eMBB User 4",
}
slot_state = {
        0:"Slot 1",
        1:"Slot 2",
        2:"Slot 3",
        3:"Slot 4",
        4:"Slot 5"
}
#A = np.array([[0.25, 0.25, 0.25, 0.25], [0.25, 0.25, 0.25, 0.25], [0.25, 0.25, 0.25, 0.25], [0.25, 0.25, 0.25,0.25]])

A = np.array([[1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000],
             [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]])

curr_state =[]
reward = []
mcs1 = 0
mcs2 = 0
mcs3 = 0
mcs4 = 0
curr_selected_mcs = []
prev_selected_mcs = 1
total_reward = 0
total_penalty = 0
reward_array = np.array([0])
steps_array = np.array([0])


N = 200
start_state = 1
print(state[start_state], "--->", end = "\n")
prev_state = start_state

slot_start_state = 0
slot_prev_state = slot_start_state


total_reward = 0
total_penalty=0
x = 3
y = 1


class probability:
    
    def __init__(self,prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs):
        self.prev_state = prev_state
        self.curr_state = curr_state
        self.reward = reward  
        self.mcs1 = mcs1
        self.mcs2 = mcs2
        self.mcs3 = mcs3
        self.mcs4 = mcs4
        self.prev_selected_mcs = prev_selected_mcs
        self.curr_selected_mcs = curr_selected_mcs
        

    def state_probability(self):
         
        if self.reward == 1:

            A[3*self.prev_state+self.prev_selected_mcs,3*self.curr_state+self.curr_selected_mcs] += x
            if self.prev_state == 0:
                if self.prev_selected_mcs == 0:
                    if self.curr_state == 0:
                        A[0,3+self.mcs2] = A[0,3+self.mcs2]-y
                        A[0,6+self.mcs3] = A[0,6+self.mcs3]-y
                        A[0,9+self.mcs4] = A[0,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[0,self.mcs1] = A[0,self.mcs1]-y
                        A[0,6+self.mcs3] = A[0,6+self.mcs3]-y
                        A[0,9+self.mcs4] = A[0,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[0,self.mcs1] = A[0,self.mcs1]-y
                        A[0,3+self.mcs2] = A[0,3+self.mcs2]-y
                        A[0,9+self.mcs4] = A[0,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[0,self.mcs1] = A[0,self.mcs1]-y
                        A[0,3+self.mcs2] = A[0,3+self.mcs2]-y
                        A[0,6+self.mcs3] = A[0,6+self.mcs3]-y
                        
                if self.prev_selected_mcs == 1:
                    if self.curr_state == 0:
                        A[1,3+self.mcs2] = A[1,3+self.mcs2]-y
                        A[1,6+self.mcs3] = A[1,6+self.mcs3]-y
                        A[1,9+self.mcs4] = A[1,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[1,self.mcs1] = A[1,self.mcs1]-y
                        A[1,6+self.mcs3] = A[1,6+self.mcs3]-y
                        A[1,9+self.mcs4] = A[1,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[1,self.mcs1] = A[1,self.mcs1]-y
                        A[1,3+self.mcs2] = A[1,3+self.mcs2]-y
                        A[1,9+self.mcs4] = A[1,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[1,self.mcs1] = A[1,self.mcs1]-y
                        A[1,3+self.mcs2] = A[1,3+self.mcs2]-y
                        A[1,6+self.mcs3] = A[1,6+self.mcs3]-y
                        
                if self.prev_selected_mcs == 2:
                    if self.curr_state == 0:
                        A[2,3+self.mcs2] = A[2,3+self.mcs2]-y
                        A[2,6+self.mcs3] = A[2,6+self.mcs3]-y
                        A[2,9+self.mcs4] = A[2,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[2,self.mcs1] = A[2,self.mcs1]-y
                        A[2,6+self.mcs3] = A[2,6+self.mcs3]-y
                        A[2,9+self.mcs4] = A[2,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[2,self.mcs1] = A[2,self.mcs1]-y
                        A[2,3+self.mcs2] = A[2,3+self.mcs2]-y
                        A[2,9+self.mcs4] = A[2,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[2,self.mcs1] = A[2,self.mcs1]-y
                        A[2,3+self.mcs2] = A[2,3+self.mcs2]-y
                        A[2,6+self.mcs3] = A[2,6+self.mcs3]-y
                        

            elif self.prev_state == 1:
                if self.prev_selected_mcs == 0:
                    if self.curr_state == 0:
                        A[3,3+self.mcs2] = A[3,3+self.mcs2]-y
                        A[3,6+self.mcs3] = A[3,6+self.mcs3]-y
                        A[3,9+self.mcs4] = A[3,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[3,self.mcs1] = A[3,self.mcs1]-y
                        A[3,6+self.mcs3] = A[3,6+self.mcs3]-y
                        A[3,9+self.mcs4] = A[3,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[3,self.mcs1] = A[3,self.mcs1]-y
                        A[3,3+self.mcs2] = A[3,3+self.mcs2]-y
                        A[3,9+self.mcs4] = A[3,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[3,self.mcs1] = A[3,self.mcs1]-y
                        A[3,3+self.mcs2] = A[3,3+self.mcs2]-y
                        A[3,6+self.mcs3] = A[3,6+self.mcs3]-y
                        
                if self.prev_selected_mcs == 1:
                    if self.curr_state == 0:
                        A[4,3+self.mcs2] = A[4,3+self.mcs2]-y
                        A[4,6+self.mcs3] = A[4,6+self.mcs3]-y
                        A[4,9+self.mcs4] = A[4,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[4,self.mcs1] = A[4,self.mcs1]-y
                        A[4,6+self.mcs3] = A[4,6+self.mcs3]-y
                        A[4,9+self.mcs4] = A[4,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[4,self.mcs1] = A[4,self.mcs1]-y
                        A[4,3+self.mcs2] = A[4,3+self.mcs2]-y
                        A[4,9+self.mcs4] = A[4,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[4,self.mcs1] = A[4,self.mcs1]-y
                        A[4,3+self.mcs2] = A[4,3+self.mcs2]-y
                        A[4,6+self.mcs3] = A[4,6+self.mcs3]-y
                        
                if self.prev_selected_mcs == 2:
                    if self.curr_state == 0:
                        A[5,3+self.mcs2] = A[5,3+self.mcs2]-y
                        A[5,6+self.mcs3] = A[5,6+self.mcs3]-y
                        A[5,9+self.mcs4] = A[5,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[5,self.mcs1] = A[5,self.mcs1]-y
                        A[5,6+self.mcs3] = A[5,6+self.mcs3]-y
                        A[5,9+self.mcs4] = A[5,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[5,self.mcs1] = A[5,self.mcs1]-y
                        A[5,3+self.mcs2] = A[5,3+self.mcs2]-y
                        A[5,9+self.mcs4] = A[5,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[5,self.mcs1] = A[5,self.mcs1]-y
                        A[5,3+self.mcs2] = A[5,3+self.mcs2]-y
                        A[5,6+self.mcs3] = A[5,6+self.mcs3]-y
                        
            elif self.prev_state == 2:
                if self.prev_selected_mcs == 0:
                    if self.curr_state == 0:
                        A[6,3+self.mcs2] = A[6,3+self.mcs2]-y
                        A[6,6+self.mcs3] = A[6,6+self.mcs3]-y
                        A[6,9+self.mcs4] = A[6,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[6,self.mcs1] = A[6,self.mcs1]-y
                        A[6,6+self.mcs3] = A[6,6+self.mcs3]-y
                        A[6,9+self.mcs4] = A[6,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[6,self.mcs1] = A[6,self.mcs1]-y
                        A[6,3+self.mcs2] = A[6,3+self.mcs2]-y
                        A[6,9+self.mcs4] = A[6,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[6,self.mcs1] = A[6,self.mcs1]-y
                        A[6,3+self.mcs2] = A[6,3+self.mcs2]-y
                        A[6,6+self.mcs3] = A[6,6+self.mcs3]-y
                        
                if self.prev_selected_mcs == 1:
                    if self.curr_state == 0:
                        A[7,3+self.mcs2] = A[7,3+self.mcs2]-y
                        A[7,6+self.mcs3] = A[7,6+self.mcs3]-y
                        A[7,9+self.mcs4] = A[7,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[7,self.mcs1] = A[7,self.mcs1]-y
                        A[7,6+self.mcs3] = A[7,6+self.mcs3]-y
                        A[7,9+self.mcs4] = A[7,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[7,self.mcs1] = A[7,self.mcs1]-y
                        A[7,3+self.mcs2] = A[7,3+self.mcs2]-y
                        A[7,9+self.mcs4] = A[7,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[7,self.mcs1] = A[7,self.mcs1]-y
                        A[7,3+self.mcs2] = A[7,3+self.mcs2]-y
                        A[7,6+self.mcs3] = A[7,6+self.mcs3]-y
                        
                if self.prev_selected_mcs == 2:
                    if self.curr_state == 0:
                        A[8,3+self.mcs2] = A[8,3+self.mcs2]-y
                        A[8,6+self.mcs3] = A[8,6+self.mcs3]-y
                        A[8,9+self.mcs4] = A[8,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[8,self.mcs1] = A[8,self.mcs1]-y
                        A[8,6+self.mcs3] = A[8,6+self.mcs3]-y
                        A[8,9+self.mcs4] = A[8,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[8,self.mcs1] = A[8,self.mcs1]-y
                        A[8,3+self.mcs2] = A[8,3+self.mcs2]-y
                        A[8,9+self.mcs4] = A[8,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[8,self.mcs1] = A[8,self.mcs1]-y
                        A[8,3+self.mcs2] = A[8,3+self.mcs2]-y
                        A[8,6+self.mcs3] = A[8,6+self.mcs3]-y

            else:
                if self.prev_selected_mcs == 0:
                    if self.curr_state == 0:
                        A[9,3+self.mcs2] = A[9,3+self.mcs2]-y
                        A[9,6+self.mcs3] = A[9,6+self.mcs3]-y
                        A[9,9+self.mcs4] = A[9,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[9,self.mcs1] = A[9,self.mcs1]-y
                        A[9,6+self.mcs3] = A[9,6+self.mcs3]-y
                        A[9,9+self.mcs4] = A[9,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[9,self.mcs1] = A[9,self.mcs1]-y
                        A[9,3+self.mcs2] = A[9,3+self.mcs2]-y
                        A[9,9+self.mcs4] = A[9,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[9,self.mcs1] = A[9,self.mcs1]-y
                        A[9,3+self.mcs2] = A[9,3+self.mcs2]-y
                        A[9,6+self.mcs3] = A[9,6+self.mcs3]-y
                        
                if self.prev_selected_mcs == 1:
                    if self.curr_state == 0:
                        A[10,3+self.mcs2] = A[10,3+self.mcs2]-y
                        A[10,6+self.mcs3] = A[10,6+self.mcs3]-y
                        A[10,9+self.mcs4] = A[10,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[10,self.mcs1] = A[10,self.mcs1]-y
                        A[10,6+self.mcs3] = A[10,6+self.mcs3]-y
                        A[10,9+self.mcs4] = A[10,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[10,self.mcs1] = A[10,self.mcs1]-y
                        A[10,3+self.mcs2] = A[10,3+self.mcs2]-y
                        A[10,9+self.mcs4] = A[10,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[10,self.mcs1] = A[10,self.mcs1]-y
                        A[10,3+self.mcs2] = A[10,3+self.mcs2]-y
                        A[10,6+self.mcs3] = A[10,6+self.mcs3]-y
                        
                if self.prev_selected_mcs == 2:
                    if self.curr_state == 0:
                        A[11,3+self.mcs2] = A[11,3+self.mcs2]-y
                        A[11,6+self.mcs3] = A[11,6+self.mcs3]-y
                        A[11,9+self.mcs4] = A[11,9+self.mcs4]-y
                    elif self.curr_state == 1:
                        A[11,self.mcs1] = A[11,self.mcs1]-y
                        A[11,6+self.mcs3] = A[11,6+self.mcs3]-y
                        A[11,9+self.mcs4] = A[11,9+self.mcs4]-y
                    elif self.curr_state == 2:
                        A[11,self.mcs1] = A[11,self.mcs1]-y
                        A[11,3+self.mcs2] = A[11,3+self.mcs2]-y
                        A[11,9+self.mcs4] = A[11,9+self.mcs4]-y
                    elif self.curr_state == 3:
                        A[11,self.mcs1] = A[11,self.mcs1]-y
                        A[11,3+self.mcs2] = A[11,3+self.mcs2]-y
                        A[11,6+self.mcs3] = A[11,6+self.mcs3]-y

    
        else:
            A[3*self.prev_state+self.prev_selected_mcs,3*self.curr_state+self.curr_selected_mcs] -= x
            if self.prev_state == 0:
                if self.prev_selected_mcs == 0:
                    if self.curr_state == 0:
                        A[0,3+self.mcs2] = A[0,3+self.mcs2]+y
                        A[0,6+self.mcs3] = A[0,6+self.mcs3]+y
                        A[0,9+self.mcs4] = A[0,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[0,self.mcs1] = A[0,self.mcs1]+y
                        A[0,6+self.mcs3] = A[0,6+self.mcs3]+y
                        A[0,9+self.mcs4] = A[0,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[0,self.mcs1] = A[0,self.mcs1]+y
                        A[0,3+self.mcs2] = A[0,3+self.mcs2]+y
                        A[0,9+self.mcs4] = A[0,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[0,self.mcs1] = A[0,self.mcs1]+y
                        A[0,3+self.mcs2] = A[0,3+self.mcs2]+y
                        A[0,6+self.mcs3] = A[0,6+self.mcs3]+y
                        
                if self.prev_selected_mcs == 1:
                    if self.curr_state == 0:
                        A[1,3+self.mcs2] = A[1,3+self.mcs2]+y
                        A[1,6+self.mcs3] = A[1,6+self.mcs3]+y
                        A[1,9+self.mcs4] = A[1,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[1,self.mcs1] = A[1,self.mcs1]+y
                        A[1,6+self.mcs3] = A[1,6+self.mcs3]+y
                        A[1,9+self.mcs4] = A[1,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[1,self.mcs1] = A[1,self.mcs1]+y
                        A[1,3+self.mcs2] = A[1,3+self.mcs2]+y
                        A[1,9+self.mcs4] = A[1,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[1,self.mcs1] = A[1,self.mcs1]+y
                        A[1,3+self.mcs2] = A[1,3+self.mcs2]+y
                        A[1,6+self.mcs3] = A[1,6+self.mcs3]+y
                        
                if self.prev_selected_mcs == 2:
                    if self.curr_state == 0:
                        A[2,3+self.mcs2] = A[2,3+self.mcs2]+y
                        A[2,6+self.mcs3] = A[2,6+self.mcs3]+y
                        A[2,9+self.mcs4] = A[2,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[2,self.mcs1] = A[2,self.mcs1]+y
                        A[2,6+self.mcs3] = A[2,6+self.mcs3]+y
                        A[2,9+self.mcs4] = A[2,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[2,self.mcs1] = A[2,self.mcs1]+y
                        A[2,3+self.mcs2] = A[2,3+self.mcs2]+y
                        A[2,9+self.mcs4] = A[2,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[2,self.mcs1] = A[2,self.mcs1]+y
                        A[2,3+self.mcs2] = A[2,3+self.mcs2]+y
                        A[2,6+self.mcs3] = A[2,6+self.mcs3]+y
                        

            elif self.prev_state == 1:
                if self.prev_selected_mcs == 0:
                    if self.curr_state == 0:
                        A[3,3+self.mcs2] = A[3,3+self.mcs2]+y
                        A[3,6+self.mcs3] = A[3,6+self.mcs3]+y
                        A[3,9+self.mcs4] = A[3,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[3,self.mcs1] = A[3,self.mcs1]+y
                        A[3,6+self.mcs3] = A[3,6+self.mcs3]+y
                        A[3,9+self.mcs4] = A[3,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[3,self.mcs1] = A[3,self.mcs1]+y
                        A[3,3+self.mcs2] = A[3,3+self.mcs2]+y
                        A[3,9+self.mcs4] = A[3,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[3,self.mcs1] = A[3,self.mcs1]+y
                        A[3,3+self.mcs2] = A[3,3+self.mcs2]+y
                        A[3,6+self.mcs3] = A[3,6+self.mcs3]+y
                        
                if self.prev_selected_mcs == 1:
                    if self.curr_state == 0:
                        A[4,3+self.mcs2] = A[4,3+self.mcs2]+y
                        A[4,6+self.mcs3] = A[4,6+self.mcs3]+y
                        A[4,9+self.mcs4] = A[4,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[4,self.mcs1] = A[4,self.mcs1]+y
                        A[4,6+self.mcs3] = A[4,6+self.mcs3]+y
                        A[4,9+self.mcs4] = A[4,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[4,self.mcs1] = A[4,self.mcs1]+y
                        A[4,3+self.mcs2] = A[4,3+self.mcs2]+y
                        A[4,9+self.mcs4] = A[4,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[4,self.mcs1] = A[4,self.mcs1]+y
                        A[4,3+self.mcs2] = A[4,3+self.mcs2]+y
                        A[4,6+self.mcs3] = A[4,6+self.mcs3]+y
                        
                if self.prev_selected_mcs == 2:
                    if self.curr_state == 0:
                        A[5,3+self.mcs2] = A[5,3+self.mcs2]+y
                        A[5,6+self.mcs3] = A[5,6+self.mcs3]+y
                        A[5,9+self.mcs4] = A[5,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[5,self.mcs1] = A[5,self.mcs1]+y
                        A[5,6+self.mcs3] = A[5,6+self.mcs3]+y
                        A[5,9+self.mcs4] = A[5,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[5,self.mcs1] = A[5,self.mcs1]+y
                        A[5,3+self.mcs2] = A[5,3+self.mcs2]+y
                        A[5,9+self.mcs4] = A[5,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[5,self.mcs1] = A[5,self.mcs1]+y
                        A[5,3+self.mcs2] = A[5,3+self.mcs2]+y
                        A[5,6+self.mcs3] = A[5,6+self.mcs3]+y
                        
            elif self.prev_state == 2:
                if self.prev_selected_mcs == 0:
                    if self.curr_state == 0:
                        A[6,3+self.mcs2] = A[6,3+self.mcs2]+y
                        A[6,6+self.mcs3] = A[6,6+self.mcs3]+y
                        A[6,9+self.mcs4] = A[6,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[6,self.mcs1] = A[6,self.mcs1]+y
                        A[6,6+self.mcs3] = A[6,6+self.mcs3]+y
                        A[6,9+self.mcs4] = A[6,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[6,self.mcs1] = A[6,self.mcs1]+y
                        A[6,3+self.mcs2] = A[6,3+self.mcs2]+y
                        A[6,9+self.mcs4] = A[6,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[6,self.mcs1] = A[6,self.mcs1]+y
                        A[6,3+self.mcs2] = A[6,3+self.mcs2]+y
                        A[6,6+self.mcs3] = A[6,6+self.mcs3]+y
                        
                if self.prev_selected_mcs == 1:
                    if self.curr_state == 0:
                        A[7,3+self.mcs2] = A[7,3+self.mcs2]+y
                        A[7,6+self.mcs3] = A[7,6+self.mcs3]+y
                        A[7,9+self.mcs4] = A[7,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[7,self.mcs1] = A[7,self.mcs1]+y
                        A[7,6+self.mcs3] = A[7,6+self.mcs3]+y
                        A[7,9+self.mcs4] = A[7,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[7,self.mcs1] = A[7,self.mcs1]+y
                        A[7,3+self.mcs2] = A[7,3+self.mcs2]+y
                        A[7,9+self.mcs4] = A[7,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[7,self.mcs1] = A[7,self.mcs1]+y
                        A[7,3+self.mcs2] = A[7,3+self.mcs2]+y
                        A[7,6+self.mcs3] = A[7,6+self.mcs3]+y
                        
                if self.prev_selected_mcs == 2:
                    if self.curr_state == 0:
                        A[8,3+self.mcs2] = A[8,3+self.mcs2]+y
                        A[8,6+self.mcs3] = A[8,6+self.mcs3]+y
                        A[8,9+self.mcs4] = A[8,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[8,self.mcs1] = A[8,self.mcs1]+y
                        A[8,6+self.mcs3] = A[8,6+self.mcs3]+y
                        A[8,9+self.mcs4] = A[8,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[8,self.mcs1] = A[8,self.mcs1]+y
                        A[8,3+self.mcs2] = A[8,3+self.mcs2]+y
                        A[8,9+self.mcs4] = A[8,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[8,self.mcs1] = A[8,self.mcs1]+y
                        A[8,3+self.mcs2] = A[8,3+self.mcs2]+y
                        A[8,6+self.mcs3] = A[8,6+self.mcs3]+y

            else:
                #reward = 0
                if self.prev_selected_mcs == 0:
                    if self.curr_state == 0:
                        A[9,3+self.mcs2] = A[9,3+self.mcs2]+y
                        A[9,6+self.mcs3] = A[9,6+self.mcs3]+y
                        A[9,9+self.mcs4] = A[9,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[9,self.mcs1] = A[9,self.mcs1]+y
                        A[9,6+self.mcs3] = A[9,6+self.mcs3]+y
                        A[9,9+self.mcs4] = A[9,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[9,self.mcs1] = A[9,self.mcs1]+y
                        A[9,3+self.mcs2] = A[9,3+self.mcs2]+y
                        A[9,9+self.mcs4] = A[9,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[9,self.mcs1] = A[9,self.mcs1]+y
                        A[9,3+self.mcs2] = A[9,3+self.mcs2]+y
                        A[9,6+self.mcs3] = A[9,6+self.mcs3]+y
                        
                if self.prev_selected_mcs == 1:
                    if self.curr_state == 0:
                        A[10,3+self.mcs2] = A[10,3+self.mcs2]+y
                        A[10,6+self.mcs3] = A[10,6+self.mcs3]+y
                        A[10,9+self.mcs4] = A[10,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[10,self.mcs1] = A[10,self.mcs1]+y
                        A[10,6+self.mcs3] = A[10,6+self.mcs3]+y
                        A[10,9+self.mcs4] = A[10,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[10,self.mcs1] = A[10,self.mcs1]+y
                        A[10,3+self.mcs2] = A[10,3+self.mcs2]+y
                        A[10,9+self.mcs4] = A[10,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[10,self.mcs1] = A[10,self.mcs1]+y
                        A[10,3+self.mcs2] = A[10,3+self.mcs2]+y
                        A[10,6+self.mcs3] = A[10,6+self.mcs3]+y
                        
                if self.prev_selected_mcs == 2:
                    if self.curr_state == 0:
                        A[11,3+self.mcs2] = A[11,3+self.mcs2]+y
                        A[11,6+self.mcs3] = A[11,6+self.mcs3]+y
                        A[11,9+self.mcs4] = A[11,9+self.mcs4]+y
                    elif self.curr_state == 1:
                        A[11,self.mcs1] = A[11,self.mcs1]+y
                        A[11,6+self.mcs3] = A[11,6+self.mcs3]+y
                        A[11,9+self.mcs4] = A[11,9+self.mcs4]+y
                    elif self.curr_state == 2:
                        A[11,self.mcs1] = A[11,self.mcs1]+y
                        A[11,3+self.mcs2] = A[11,3+self.mcs2]+y
                        A[11,9+self.mcs4] = A[11,9+self.mcs4]+y
                    elif self.curr_state == 3:
                        A[11,self.mcs1] = A[11,self.mcs1]+y
                        A[11,3+self.mcs2] = A[11,3+self.mcs2]+y
                        A[11,6+self.mcs3] = A[11,6+self.mcs3]+y
                        
       # A[3*self.prev_state+self.prev_selected_mcs,3*self.curr_state+self.curr_selected_mcs]
        
        if  A[3*self.prev_state + self.prev_selected_mcs, self.mcs1] >= 0:
            A[3*self.prev_state + self.prev_selected_mcs, self.mcs1] = A[3*self.prev_state + self.prev_selected_mcs, self.mcs1]
        else:
            A[3*self.prev_state + self.prev_selected_mcs, self.mcs1] = 0

        if  A[3*self.prev_state + self.prev_selected_mcs,3 + self.mcs2] >= 0:
            A[3*self.prev_state + self.prev_selected_mcs,3 + self.mcs2] = A[3*self.prev_state + self.prev_selected_mcs,3 + self.mcs2]
        else:
            A[3*self.prev_state + self.prev_selected_mcs,3 + self.mcs2] = 0
            
        if  A[3*self.prev_state + self.prev_selected_mcs, 6 + self.mcs3] >= 0:
            A[3*self.prev_state + self.prev_selected_mcs, 6 + self.mcs3] = A[3*self.prev_state + self.prev_selected_mcs, 6 + self.mcs3]
        else:
            A[3*self.prev_state + self.prev_selected_mcs, 6 + self.mcs3] = 0
            
        if  A[3*self.prev_state + self.prev_selected_mcs, 9 + self.mcs4] >= 0:
            A[3*self.prev_state + self.prev_selected_mcs, 9 + self.mcs4] = A[3*self.prev_state + self.prev_selected_mcs, 9 + self.mcs4]
        else:
            A[3*self.prev_state + self.prev_selected_mcs, 9 + self.mcs4] = 0
        
   
        return A
    

    def totalRewards(self):
        if self.reward == 1:
            total_reward = total_reward + 1
        else:
            total_penalty = total_penalty + 1
        
        return (total_reward-total_penalty)
        
#selected_eMBB_user = []

transition_probability0 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability1 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability2 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability3 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability4 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability5 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability6 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability7 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability8 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability9 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability10 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability11 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability12 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability13 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability14 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability15 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability16 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability17 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability18 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability19 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability20 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability21 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability22 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability23 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
transition_probability24 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)


for n in range(1, N):
    
    mcs1 = int(dataset.values[n, 5])
    mcs2 = int(dataset.values[n, 6])
    mcs3 = int(dataset.values[n, 7])
    mcs4 = int(dataset.values[n, 8])
    slot_curr_state = dataset.values[n, 4]
    print("Time slot =", n, " ,", slot_state[slot_curr_state], end = " ,")
    
    
    if slot_prev_state == 0 and slot_curr_state == 0:
        
        A0 = transition_probability0.state_probability()
        A0a = A0[3*prev_state+prev_selected_mcs,mcs1]/(A0[3*prev_state+prev_selected_mcs,mcs1]+A0[3*prev_state+prev_selected_mcs,mcs2+3]+A0[3*prev_state+prev_selected_mcs,mcs3+6]+A0[3*prev_state+prev_selected_mcs,mcs4+9])
        A0b = A0[3*prev_state+prev_selected_mcs,mcs2+3]/(A0[3*prev_state+prev_selected_mcs,mcs1]+A0[3*prev_state+prev_selected_mcs,mcs2+3]+A0[3*prev_state+prev_selected_mcs,mcs3+6]+A0[3*prev_state+prev_selected_mcs,mcs4+9])
        A0c = A0[3*prev_state+prev_selected_mcs,mcs3+6]/(A0[3*prev_state+prev_selected_mcs,mcs1]+A0[3*prev_state+prev_selected_mcs,mcs2+3]+A0[3*prev_state+prev_selected_mcs,mcs3+6]+A0[3*prev_state+prev_selected_mcs,mcs4+9])
        A0d = A0[3*prev_state+prev_selected_mcs,mcs4+9]/(A0[3*prev_state+prev_selected_mcs,mcs1]+A0[3*prev_state+prev_selected_mcs,mcs2+3]+A0[3*prev_state+prev_selected_mcs,mcs3+6]+A0[3*prev_state+prev_selected_mcs,mcs4+9])
        
        curr_state = np.random.choice([0, 1, 2, 3], p = [A0a, A0b, A0c, A0d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
                           
        transition_probability0 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A0 =",transition_probability0.state_probability(),"--->", end = "\n\n")
                               
            
    elif slot_prev_state == 0 and slot_curr_state == 1:
        A1 = transition_probability1.state_probability()

        A1a = A1[3*prev_state+prev_selected_mcs,mcs1]/(A1[3*prev_state+prev_selected_mcs,mcs1]+A1[3*prev_state+prev_selected_mcs,mcs2+3]+A1[3*prev_state+prev_selected_mcs,mcs3+6]+A1[3*prev_state+prev_selected_mcs,mcs4+9])
        A1b = A1[3*prev_state+prev_selected_mcs,mcs2+3]/(A1[3*prev_state+prev_selected_mcs,mcs1]+A1[3*prev_state+prev_selected_mcs,mcs2+3]+A1[3*prev_state+prev_selected_mcs,mcs3+6]+A1[3*prev_state+prev_selected_mcs,mcs4+9])
        A1c = A1[3*prev_state+prev_selected_mcs,mcs3+6]/(A1[3*prev_state+prev_selected_mcs,mcs1]+A1[3*prev_state+prev_selected_mcs,mcs2+3]+A1[3*prev_state+prev_selected_mcs,mcs3+6]+A1[3*prev_state+prev_selected_mcs,mcs4+9])
        A1d = A1[3*prev_state+prev_selected_mcs,mcs4+9]/(A1[3*prev_state+prev_selected_mcs,mcs1]+A1[3*prev_state+prev_selected_mcs,mcs2+3]+A1[3*prev_state+prev_selected_mcs,mcs3+6]+A1[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A1a, A1b, A1c, A1d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
               
        transition_probability1 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A1 =",transition_probability1.state_probability(),"--->", end = "\n\n")
                               
        
    elif slot_prev_state == 0 and slot_curr_state == 2:
        A2 = transition_probability2.state_probability()

        A2a = A2[3*prev_state+prev_selected_mcs,mcs1]/(A2[3*prev_state+prev_selected_mcs,mcs1]+A2[3*prev_state+prev_selected_mcs,mcs2+3]+A2[3*prev_state+prev_selected_mcs,mcs3+6]+A2[3*prev_state+prev_selected_mcs,mcs4+9])
        A2b = A2[3*prev_state+prev_selected_mcs,mcs2+3]/(A2[3*prev_state+prev_selected_mcs,mcs1]+A2[3*prev_state+prev_selected_mcs,mcs2+3]+A2[3*prev_state+prev_selected_mcs,mcs3+6]+A2[3*prev_state+prev_selected_mcs,mcs4+9])
        A2c = A2[3*prev_state+prev_selected_mcs,mcs3+6]/(A2[3*prev_state+prev_selected_mcs,mcs1]+A2[3*prev_state+prev_selected_mcs,mcs2+3]+A2[3*prev_state+prev_selected_mcs,mcs3+6]+A2[3*prev_state+prev_selected_mcs,mcs4+9])
        A2d = A2[3*prev_state+prev_selected_mcs,mcs4+9]/(A2[3*prev_state+prev_selected_mcs,mcs1]+A2[3*prev_state+prev_selected_mcs,mcs2+3]+A2[3*prev_state+prev_selected_mcs,mcs3+6]+A2[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A2a, A2b, A2c, A2d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
        
        transition_probability2 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A2 =",transition_probability2.state_probability(),"--->", end = "\n\n")
                                  
                                               
    elif slot_prev_state == 0 and slot_curr_state == 3:
        A3 = transition_probability3.state_probability()

        A3a = A3[3*prev_state+prev_selected_mcs,mcs1]/(A3[3*prev_state+prev_selected_mcs,mcs1]+A3[3*prev_state+prev_selected_mcs,mcs2+3]+A3[3*prev_state+prev_selected_mcs,mcs3+6]+A3[3*prev_state+prev_selected_mcs,mcs4+9])
        A3b = A3[3*prev_state+prev_selected_mcs,mcs2+3]/(A3[3*prev_state+prev_selected_mcs,mcs1]+A3[3*prev_state+prev_selected_mcs,mcs2+3]+A3[3*prev_state+prev_selected_mcs,mcs3+6]+A3[3*prev_state+prev_selected_mcs,mcs4+9])
        A3c = A3[3*prev_state+prev_selected_mcs,mcs3+6]/(A3[3*prev_state+prev_selected_mcs,mcs1]+A3[3*prev_state+prev_selected_mcs,mcs2+3]+A3[3*prev_state+prev_selected_mcs,mcs3+6]+A3[3*prev_state+prev_selected_mcs,mcs4+9])
        A3d = A3[3*prev_state+prev_selected_mcs,mcs4+9]/(A3[3*prev_state+prev_selected_mcs,mcs1]+A3[3*prev_state+prev_selected_mcs,mcs2+3]+A3[3*prev_state+prev_selected_mcs,mcs3+6]+A3[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A3a, A3b, A3c, A3d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
        
        transition_probability3 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A3 =",transition_probability3.state_probability(),"--->", end = "\n\n")
        
        
    elif slot_prev_state == 0 and slot_curr_state == 4:
        A4 = transition_probability4.state_probability()

        A4a = A4[3*prev_state+prev_selected_mcs,mcs1]/(A4[3*prev_state+prev_selected_mcs,mcs1]+A4[3*prev_state+prev_selected_mcs,mcs2+3]+A4[3*prev_state+prev_selected_mcs,mcs3+6]+A4[3*prev_state+prev_selected_mcs,mcs4+9])
        A4b = A4[3*prev_state+prev_selected_mcs,mcs2+3]/(A4[3*prev_state+prev_selected_mcs,mcs1]+A4[3*prev_state+prev_selected_mcs,mcs2+3]+A4[3*prev_state+prev_selected_mcs,mcs3+6]+A4[3*prev_state+prev_selected_mcs,mcs4+9])
        A4c = A4[3*prev_state+prev_selected_mcs,mcs3+6]/(A4[3*prev_state+prev_selected_mcs,mcs1]+A4[3*prev_state+prev_selected_mcs,mcs2+3]+A4[3*prev_state+prev_selected_mcs,mcs3+6]+A4[3*prev_state+prev_selected_mcs,mcs4+9])
        A4d = A4[3*prev_state+prev_selected_mcs,mcs4+9]/(A4[3*prev_state+prev_selected_mcs,mcs1]+A4[3*prev_state+prev_selected_mcs,mcs2+3]+A4[3*prev_state+prev_selected_mcs,mcs3+6]+A4[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A4a, A4b, A4c, A4d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability4 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A4 =",transition_probability4.state_probability(),"--->", end = "\n\n")
        
    
    elif slot_prev_state == 1 and slot_curr_state == 0:
        A5 = transition_probability5.state_probability()

        A5a = A5[3*prev_state+prev_selected_mcs,mcs1]/(A5[3*prev_state+prev_selected_mcs,mcs1]+A5[3*prev_state+prev_selected_mcs,mcs2+3]+A5[3*prev_state+prev_selected_mcs,mcs3+6]+A5[3*prev_state+prev_selected_mcs,mcs4+9])
        A5b = A5[3*prev_state+prev_selected_mcs,mcs2+3]/(A5[3*prev_state+prev_selected_mcs,mcs1]+A5[3*prev_state+prev_selected_mcs,mcs2+3]+A5[3*prev_state+prev_selected_mcs,mcs3+6]+A5[3*prev_state+prev_selected_mcs,mcs4+9])
        A5c = A5[3*prev_state+prev_selected_mcs,mcs3+6]/(A5[3*prev_state+prev_selected_mcs,mcs1]+A5[3*prev_state+prev_selected_mcs,mcs2+3]+A5[3*prev_state+prev_selected_mcs,mcs3+6]+A5[3*prev_state+prev_selected_mcs,mcs4+9])
        A5d = A5[3*prev_state+prev_selected_mcs,mcs4+9]/(A5[3*prev_state+prev_selected_mcs,mcs1]+A5[3*prev_state+prev_selected_mcs,mcs2+3]+A5[3*prev_state+prev_selected_mcs,mcs3+6]+A5[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A5a, A5b, A5c, A5d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability5 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A5 =",transition_probability5.state_probability(),"--->", end = "\n\n")
                              
                        
    elif slot_prev_state == 1 and slot_curr_state == 1:
        A6 = transition_probability6.state_probability()

        A6a = A6[3*prev_state+prev_selected_mcs,mcs1]/(A6[3*prev_state+prev_selected_mcs,mcs1]+A6[3*prev_state+prev_selected_mcs,mcs2+3]+A6[3*prev_state+prev_selected_mcs,mcs3+6]+A6[3*prev_state+prev_selected_mcs,mcs4+9])
        A6b = A6[3*prev_state+prev_selected_mcs,mcs2+3]/(A6[3*prev_state+prev_selected_mcs,mcs1]+A6[3*prev_state+prev_selected_mcs,mcs2+3]+A6[3*prev_state+prev_selected_mcs,mcs3+6]+A6[3*prev_state+prev_selected_mcs,mcs4+9])
        A6c = A6[3*prev_state+prev_selected_mcs,mcs3+6]/(A6[3*prev_state+prev_selected_mcs,mcs1]+A6[3*prev_state+prev_selected_mcs,mcs2+3]+A6[3*prev_state+prev_selected_mcs,mcs3+6]+A6[3*prev_state+prev_selected_mcs,mcs4+9])
        A6d = A6[3*prev_state+prev_selected_mcs,mcs4+9]/(A6[3*prev_state+prev_selected_mcs,mcs1]+A6[3*prev_state+prev_selected_mcs,mcs2+3]+A6[3*prev_state+prev_selected_mcs,mcs3+6]+A6[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A6a, A6b, A6c, A6d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
                
        transition_probability6 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs) 
        print(state[curr_state], ", reward =",reward,"\nAlpha_A6 =",transition_probability6.state_probability(),"--->", end = "\n\n")

                              
    elif slot_prev_state == 1 and slot_curr_state == 2:
        A7 = transition_probability7.state_probability()

        A7a = A7[3*prev_state+prev_selected_mcs,mcs1]/(A7[3*prev_state+prev_selected_mcs,mcs1]+A7[3*prev_state+prev_selected_mcs,mcs2+3]+A7[3*prev_state+prev_selected_mcs,mcs3+6]+A7[3*prev_state+prev_selected_mcs,mcs4+9])
        A7b = A7[3*prev_state+prev_selected_mcs,mcs2+3]/(A7[3*prev_state+prev_selected_mcs,mcs1]+A7[3*prev_state+prev_selected_mcs,mcs2+3]+A7[3*prev_state+prev_selected_mcs,mcs3+6]+A7[3*prev_state+prev_selected_mcs,mcs4+9])
        A7c = A7[3*prev_state+prev_selected_mcs,mcs3+6]/(A7[3*prev_state+prev_selected_mcs,mcs1]+A7[3*prev_state+prev_selected_mcs,mcs2+3]+A7[3*prev_state+prev_selected_mcs,mcs3+6]+A7[3*prev_state+prev_selected_mcs,mcs4+9])
        A7d = A7[3*prev_state+prev_selected_mcs,mcs4+9]/(A7[3*prev_state+prev_selected_mcs,mcs1]+A7[3*prev_state+prev_selected_mcs,mcs2+3]+A7[3*prev_state+prev_selected_mcs,mcs3+6]+A7[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A7a, A7b, A7c, A7d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
        
        transition_probability7 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A7 =",transition_probability7.state_probability(),"--->", end = "\n\n")
                          
                               
    elif slot_prev_state == 1 and slot_curr_state == 3:
        A8 = transition_probability8.state_probability()

        A8a = A8[3*prev_state+prev_selected_mcs,mcs1]/(A8[3*prev_state+prev_selected_mcs,mcs1]+A8[3*prev_state+prev_selected_mcs,mcs2+3]+A8[3*prev_state+prev_selected_mcs,mcs3+6]+A8[3*prev_state+prev_selected_mcs,mcs4+9])
        A8b = A8[3*prev_state+prev_selected_mcs,mcs2+3]/(A8[3*prev_state+prev_selected_mcs,mcs1]+A8[3*prev_state+prev_selected_mcs,mcs2+3]+A8[3*prev_state+prev_selected_mcs,mcs3+6]+A8[3*prev_state+prev_selected_mcs,mcs4+9])
        A8c = A8[3*prev_state+prev_selected_mcs,mcs3+6]/(A8[3*prev_state+prev_selected_mcs,mcs1]+A8[3*prev_state+prev_selected_mcs,mcs2+3]+A8[3*prev_state+prev_selected_mcs,mcs3+6]+A8[3*prev_state+prev_selected_mcs,mcs4+9])
        A8d = A8[3*prev_state+prev_selected_mcs,mcs4+9]/(A8[3*prev_state+prev_selected_mcs,mcs1]+A8[3*prev_state+prev_selected_mcs,mcs2+3]+A8[3*prev_state+prev_selected_mcs,mcs3+6]+A8[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A8a, A8b, A8c, A8d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
        
        transition_probability8 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A8 =",transition_probability8.state_probability(),"--->", end = "\n\n")
                                
                               
    elif slot_prev_state == 1 and slot_curr_state == 4:
        A9 = transition_probability9.state_probability()

        A9a = A9[3*prev_state+prev_selected_mcs,mcs1]/(A9[3*prev_state+prev_selected_mcs,mcs1]+A9[3*prev_state+prev_selected_mcs,mcs2+3]+A9[3*prev_state+prev_selected_mcs,mcs3+6]+A9[3*prev_state+prev_selected_mcs,mcs4+9])
        A9b = A9[3*prev_state+prev_selected_mcs,mcs2+3]/(A9[3*prev_state+prev_selected_mcs,mcs1]+A9[3*prev_state+prev_selected_mcs,mcs2+3]+A9[3*prev_state+prev_selected_mcs,mcs3+6]+A9[3*prev_state+prev_selected_mcs,mcs4+9])
        A9c = A9[3*prev_state+prev_selected_mcs,mcs3+6]/(A9[3*prev_state+prev_selected_mcs,mcs1]+A9[3*prev_state+prev_selected_mcs,mcs2+3]+A9[3*prev_state+prev_selected_mcs,mcs3+6]+A9[3*prev_state+prev_selected_mcs,mcs4+9])
        A9d = A9[3*prev_state+prev_selected_mcs,mcs4+9]/(A9[3*prev_state+prev_selected_mcs,mcs1]+A9[3*prev_state+prev_selected_mcs,mcs2+3]+A9[3*prev_state+prev_selected_mcs,mcs3+6]+A9[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A9a, A9b, A9c, A9d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability9 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A9 =",transition_probability9.state_probability(),"--->", end = "\n\n")
        
                        
    elif slot_prev_state == 2 and slot_curr_state == 0:
        A10 = transition_probability10.state_probability()

        A10a = A10[3*prev_state+prev_selected_mcs,mcs1]/(A10[3*prev_state+prev_selected_mcs,mcs1]+A10[3*prev_state+prev_selected_mcs,mcs2+3]+A10[3*prev_state+prev_selected_mcs,mcs3+6]+A10[3*prev_state+prev_selected_mcs,mcs4+9])
        A10b = A10[3*prev_state+prev_selected_mcs,mcs2+3]/(A10[3*prev_state+prev_selected_mcs,mcs1]+A10[3*prev_state+prev_selected_mcs,mcs2+3]+A10[3*prev_state+prev_selected_mcs,mcs3+6]+A10[3*prev_state+prev_selected_mcs,mcs4+9])
        A10c = A10[3*prev_state+prev_selected_mcs,mcs3+6]/(A10[3*prev_state+prev_selected_mcs,mcs1]+A10[3*prev_state+prev_selected_mcs,mcs2+3]+A10[3*prev_state+prev_selected_mcs,mcs3+6]+A10[3*prev_state+prev_selected_mcs,mcs4+9])
        A10d = A10[3*prev_state+prev_selected_mcs,mcs4+9]/(A10[3*prev_state+prev_selected_mcs,mcs1]+A10[3*prev_state+prev_selected_mcs,mcs2+3]+A10[3*prev_state+prev_selected_mcs,mcs3+6]+A10[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A10a, A10b, A10c, A10d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
                
        transition_probability10 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward, "\nAlpha_A10 =",transition_probability10.state_probability(),"--->", end = "\n\n")
                                 
                        
    elif slot_prev_state == 2 and slot_curr_state == 1:
        A11 = transition_probability11.state_probability()

        A11a = A11[3*prev_state+prev_selected_mcs,mcs1]/(A11[3*prev_state+prev_selected_mcs,mcs1]+A11[3*prev_state+prev_selected_mcs,mcs2+3]+A11[3*prev_state+prev_selected_mcs,mcs3+6]+A11[3*prev_state+prev_selected_mcs,mcs4+9])
        A11b = A11[3*prev_state+prev_selected_mcs,mcs2+3]/(A11[3*prev_state+prev_selected_mcs,mcs1]+A11[3*prev_state+prev_selected_mcs,mcs2+3]+A11[3*prev_state+prev_selected_mcs,mcs3+6]+A11[3*prev_state+prev_selected_mcs,mcs4+9])
        A11c = A11[3*prev_state+prev_selected_mcs,mcs3+6]/(A11[3*prev_state+prev_selected_mcs,mcs1]+A11[3*prev_state+prev_selected_mcs,mcs2+3]+A11[3*prev_state+prev_selected_mcs,mcs3+6]+A11[3*prev_state+prev_selected_mcs,mcs4+9])
        A11d = A11[3*prev_state+prev_selected_mcs,mcs4+9]/(A11[3*prev_state+prev_selected_mcs,mcs1]+A11[3*prev_state+prev_selected_mcs,mcs2+3]+A11[3*prev_state+prev_selected_mcs,mcs3+6]+A11[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A11a, A11b, A11c, A11d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
             
        transition_probability11 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A11 =",transition_probability11.state_probability(),"--->", end = "\n\n")
                         
                          
    elif slot_prev_state == 2 and slot_curr_state == 2:
        A12 = transition_probability12.state_probability()

        A12a = A12[3*prev_state+prev_selected_mcs,mcs1]/(A12[3*prev_state+prev_selected_mcs,mcs1]+A12[3*prev_state+prev_selected_mcs,mcs2+3]+A12[3*prev_state+prev_selected_mcs,mcs3+6]+A12[3*prev_state+prev_selected_mcs,mcs4+9])
        A12b = A12[3*prev_state+prev_selected_mcs,mcs2+3]/(A12[3*prev_state+prev_selected_mcs,mcs1]+A12[3*prev_state+prev_selected_mcs,mcs2+3]+A12[3*prev_state+prev_selected_mcs,mcs3+6]+A12[3*prev_state+prev_selected_mcs,mcs4+9])
        A12c = A12[3*prev_state+prev_selected_mcs,mcs3+6]/(A12[3*prev_state+prev_selected_mcs,mcs1]+A12[3*prev_state+prev_selected_mcs,mcs2+3]+A12[3*prev_state+prev_selected_mcs,mcs3+6]+A12[3*prev_state+prev_selected_mcs,mcs4+9])
        A12d = A12[3*prev_state+prev_selected_mcs,mcs4+9]/(A12[3*prev_state+prev_selected_mcs,mcs1]+A12[3*prev_state+prev_selected_mcs,mcs2+3]+A12[3*prev_state+prev_selected_mcs,mcs3+6]+A12[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A12a, A12b, A12c, A12d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
               
        transition_probability12 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward, "\nAlpha_A12 =",transition_probability12.state_probability(),"--->",end = "\n\n")
                              
                            
    elif slot_prev_state == 2 and slot_curr_state == 3:
        A13 = transition_probability13.state_probability()

        A13a = A13[3*prev_state+prev_selected_mcs,mcs1]/(A13[3*prev_state+prev_selected_mcs,mcs1]+A13[3*prev_state+prev_selected_mcs,mcs2+3]+A13[3*prev_state+prev_selected_mcs,mcs3+6]+A13[3*prev_state+prev_selected_mcs,mcs4+9])
        A13b = A13[3*prev_state+prev_selected_mcs,mcs2+3]/(A13[3*prev_state+prev_selected_mcs,mcs1]+A13[3*prev_state+prev_selected_mcs,mcs2+3]+A13[3*prev_state+prev_selected_mcs,mcs3+6]+A13[3*prev_state+prev_selected_mcs,mcs4+9])
        A13c = A13[3*prev_state+prev_selected_mcs,mcs3+6]/(A13[3*prev_state+prev_selected_mcs,mcs1]+A13[3*prev_state+prev_selected_mcs,mcs2+3]+A13[3*prev_state+prev_selected_mcs,mcs3+6]+A13[3*prev_state+prev_selected_mcs,mcs4+9])
        A13d = A13[3*prev_state+prev_selected_mcs,mcs4+9]/(A13[3*prev_state+prev_selected_mcs,mcs1]+A13[3*prev_state+prev_selected_mcs,mcs2+3]+A13[3*prev_state+prev_selected_mcs,mcs3+6]+A13[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A13a, A13b, A13c, A13d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
        
        transition_probability13 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A13 =",transition_probability13.state_probability(),"--->", end = "\n\n")
                                 
                              
    elif slot_prev_state == 2 and slot_curr_state == 4:
        A14 = transition_probability14.state_probability()

        A14a = A14[3*prev_state+prev_selected_mcs,mcs1]/(A14[3*prev_state+prev_selected_mcs,mcs1]+A14[3*prev_state+prev_selected_mcs,mcs2+3]+A14[3*prev_state+prev_selected_mcs,mcs3+6]+A14[3*prev_state+prev_selected_mcs,mcs4+9])
        A14b = A14[3*prev_state+prev_selected_mcs,mcs2+3]/(A14[3*prev_state+prev_selected_mcs,mcs1]+A14[3*prev_state+prev_selected_mcs,mcs2+3]+A14[3*prev_state+prev_selected_mcs,mcs3+6]+A14[3*prev_state+prev_selected_mcs,mcs4+9])
        A14c = A14[3*prev_state+prev_selected_mcs,mcs3+6]/(A14[3*prev_state+prev_selected_mcs,mcs1]+A14[3*prev_state+prev_selected_mcs,mcs2+3]+A14[3*prev_state+prev_selected_mcs,mcs3+6]+A14[3*prev_state+prev_selected_mcs,mcs4+9])
        A14d = A14[3*prev_state+prev_selected_mcs,mcs4+9]/(A14[3*prev_state+prev_selected_mcs,mcs1]+A14[3*prev_state+prev_selected_mcs,mcs2+3]+A14[3*prev_state+prev_selected_mcs,mcs3+6]+A14[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A14a, A14b, A14c, A14d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
        
        transition_probability14 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A14 =",transition_probability14.state_probability(),"--->", end = " \n\n")
                                 
                            
    elif slot_prev_state == 3 and slot_curr_state == 0:
        A15 = transition_probability15.state_probability()

        A15a = A15[3*prev_state+prev_selected_mcs,mcs1]/(A15[3*prev_state+prev_selected_mcs,mcs1]+A15[3*prev_state+prev_selected_mcs,mcs2+3]+A15[3*prev_state+prev_selected_mcs,mcs3+6]+A15[3*prev_state+prev_selected_mcs,mcs4+9])
        A15b = A15[3*prev_state+prev_selected_mcs,mcs2+3]/(A15[3*prev_state+prev_selected_mcs,mcs1]+A15[3*prev_state+prev_selected_mcs,mcs2+3]+A15[3*prev_state+prev_selected_mcs,mcs3+6]+A15[3*prev_state+prev_selected_mcs,mcs4+9])
        A15c = A15[3*prev_state+prev_selected_mcs,mcs3+6]/(A15[3*prev_state+prev_selected_mcs,mcs1]+A15[3*prev_state+prev_selected_mcs,mcs2+3]+A15[3*prev_state+prev_selected_mcs,mcs3+6]+A15[3*prev_state+prev_selected_mcs,mcs4+9])
        A15d = A15[3*prev_state+prev_selected_mcs,mcs4+9]/(A15[3*prev_state+prev_selected_mcs,mcs1]+A15[3*prev_state+prev_selected_mcs,mcs2+3]+A15[3*prev_state+prev_selected_mcs,mcs3+6]+A15[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A15a, A15b, A15c, A15d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
        
        transition_probability15 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A15 =",transition_probability15.state_probability(),"--->", end = "\n\n")
                              
                               
    elif slot_prev_state == 3 and slot_curr_state == 1:
        A16 = transition_probability16.state_probability()

        A16a = A16[3*prev_state+prev_selected_mcs,mcs1]/(A16[3*prev_state+prev_selected_mcs,mcs1]+A16[3*prev_state+prev_selected_mcs,mcs2+3]+A16[3*prev_state+prev_selected_mcs,mcs3+6]+A16[3*prev_state+prev_selected_mcs,mcs4+9])
        A16b = A16[3*prev_state+prev_selected_mcs,mcs2+3]/(A16[3*prev_state+prev_selected_mcs,mcs1]+A16[3*prev_state+prev_selected_mcs,mcs2+3]+A16[3*prev_state+prev_selected_mcs,mcs3+6]+A16[3*prev_state+prev_selected_mcs,mcs4+9])
        A16c = A16[3*prev_state+prev_selected_mcs,mcs3+6]/(A16[3*prev_state+prev_selected_mcs,mcs1]+A16[3*prev_state+prev_selected_mcs,mcs2+3]+A16[3*prev_state+prev_selected_mcs,mcs3+6]+A16[3*prev_state+prev_selected_mcs,mcs4+9])
        A16d = A16[3*prev_state+prev_selected_mcs,mcs4+9]/(A16[3*prev_state+prev_selected_mcs,mcs1]+A16[3*prev_state+prev_selected_mcs,mcs2+3]+A16[3*prev_state+prev_selected_mcs,mcs3+6]+A16[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A16a, A16b, A16c, A16d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability16 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward, "\nAlpha_A16 =",transition_probability16.state_probability(),"--->", end = "\n\n")
                                       
                        
    elif slot_prev_state == 3 and slot_curr_state == 2:
        A17 = transition_probability17.state_probability()

        A17a = A17[3*prev_state+prev_selected_mcs,mcs1]/(A17[3*prev_state+prev_selected_mcs,mcs1]+A17[3*prev_state+prev_selected_mcs,mcs2+3]+A17[3*prev_state+prev_selected_mcs,mcs3+6]+A17[3*prev_state+prev_selected_mcs,mcs4+9])
        A17b = A17[3*prev_state+prev_selected_mcs,mcs2+3]/(A17[3*prev_state+prev_selected_mcs,mcs1]+A17[3*prev_state+prev_selected_mcs,mcs2+3]+A17[3*prev_state+prev_selected_mcs,mcs3+6]+A17[3*prev_state+prev_selected_mcs,mcs4+9])
        A17c = A17[3*prev_state+prev_selected_mcs,mcs3+6]/(A17[3*prev_state+prev_selected_mcs,mcs1]+A17[3*prev_state+prev_selected_mcs,mcs2+3]+A17[3*prev_state+prev_selected_mcs,mcs3+6]+A17[3*prev_state+prev_selected_mcs,mcs4+9])
        A17d = A17[3*prev_state+prev_selected_mcs,mcs4+9]/(A17[3*prev_state+prev_selected_mcs,mcs1]+A17[3*prev_state+prev_selected_mcs,mcs2+3]+A17[3*prev_state+prev_selected_mcs,mcs3+6]+A17[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A17a, A17b, A17c, A17d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
                
        transition_probability17 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward, "\nAlpha_A17 =",transition_probability17.state_probability(),"--->" ,end = " \n\n")
                                         
        
    elif slot_prev_state == 3 and slot_curr_state == 3:
        A18 = transition_probability18.state_probability()

        A18a = A18[3*prev_state+prev_selected_mcs,mcs1]/(A18[3*prev_state+prev_selected_mcs,mcs1]+A18[3*prev_state+prev_selected_mcs,mcs2+3]+A18[3*prev_state+prev_selected_mcs,mcs3+6]+A18[3*prev_state+prev_selected_mcs,mcs4+9])
        A18b = A18[3*prev_state+prev_selected_mcs,mcs2+3]/(A18[3*prev_state+prev_selected_mcs,mcs1]+A18[3*prev_state+prev_selected_mcs,mcs2+3]+A18[3*prev_state+prev_selected_mcs,mcs3+6]+A18[3*prev_state+prev_selected_mcs,mcs4+9])
        A18c = A18[3*prev_state+prev_selected_mcs,mcs3+6]/(A18[3*prev_state+prev_selected_mcs,mcs1]+A18[3*prev_state+prev_selected_mcs,mcs2+3]+A18[3*prev_state+prev_selected_mcs,mcs3+6]+A18[3*prev_state+prev_selected_mcs,mcs4+9])
        A18d = A18[3*prev_state+prev_selected_mcs,mcs4+9]/(A18[3*prev_state+prev_selected_mcs,mcs1]+A18[3*prev_state+prev_selected_mcs,mcs2+3]+A18[3*prev_state+prev_selected_mcs,mcs3+6]+A18[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A18a, A18b, A18c, A18d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
    
        transition_probability18 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A18 =",transition_probability18.state_probability(),"--->", end = "\n\n")
                              
                              
    elif slot_prev_state == 3 and slot_curr_state == 4:
        A19 = transition_probability19.state_probability()

        A19a = A19[3*prev_state+prev_selected_mcs,mcs1]/(A19[3*prev_state+prev_selected_mcs,mcs1]+A19[3*prev_state+prev_selected_mcs,mcs2+3]+A19[3*prev_state+prev_selected_mcs,mcs3+6]+A19[3*prev_state+prev_selected_mcs,mcs4+9])
        A19b = A19[3*prev_state+prev_selected_mcs,mcs2+3]/(A19[3*prev_state+prev_selected_mcs,mcs1]+A19[3*prev_state+prev_selected_mcs,mcs2+3]+A19[3*prev_state+prev_selected_mcs,mcs3+6]+A19[3*prev_state+prev_selected_mcs,mcs4+9])
        A19c = A19[3*prev_state+prev_selected_mcs,mcs3+6]/(A19[3*prev_state+prev_selected_mcs,mcs1]+A19[3*prev_state+prev_selected_mcs,mcs2+3]+A19[3*prev_state+prev_selected_mcs,mcs3+6]+A19[3*prev_state+prev_selected_mcs,mcs4+9])
        A19d = A19[3*prev_state+prev_selected_mcs,mcs4+9]/(A19[3*prev_state+prev_selected_mcs,mcs1]+A19[3*prev_state+prev_selected_mcs,mcs2+3]+A19[3*prev_state+prev_selected_mcs,mcs3+6]+A19[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A19a, A19b, A19c, A19d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability19 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A19 =",transition_probability19.state_probability(),"--->", end = "\n\n")
                                                        
    
    elif slot_prev_state == 4 and slot_curr_state == 0:
        A20 = transition_probability20.state_probability()

        A20a = A20[3*prev_state+prev_selected_mcs,mcs1]/(A20[3*prev_state+prev_selected_mcs,mcs1]+A20[3*prev_state+prev_selected_mcs,mcs2+3]+A20[3*prev_state+prev_selected_mcs,mcs3+6]+A20[3*prev_state+prev_selected_mcs,mcs4+9])
        A20b = A20[3*prev_state+prev_selected_mcs,mcs2+3]/(A20[3*prev_state+prev_selected_mcs,mcs1]+A20[3*prev_state+prev_selected_mcs,mcs2+3]+A20[3*prev_state+prev_selected_mcs,mcs3+6]+A20[3*prev_state+prev_selected_mcs,mcs4+9])
        A20c = A20[3*prev_state+prev_selected_mcs,mcs3+6]/(A20[3*prev_state+prev_selected_mcs,mcs1]+A20[3*prev_state+prev_selected_mcs,mcs2+3]+A20[3*prev_state+prev_selected_mcs,mcs3+6]+A20[3*prev_state+prev_selected_mcs,mcs4+9])
        A20d = A20[3*prev_state+prev_selected_mcs,mcs4+9]/(A20[3*prev_state+prev_selected_mcs,mcs1]+A20[3*prev_state+prev_selected_mcs,mcs2+3]+A20[3*prev_state+prev_selected_mcs,mcs3+6]+A20[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A20a, A20b, A20c, A20d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0
        
        transition_probability20 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward, "\nAlpha_A20 =",transition_probability20.state_probability(),"--->",end = "\n\n ")
                                         
                        
    elif slot_prev_state == 4 and slot_curr_state == 1:
        A21 = transition_probability21.state_probability()

        A21a = A21[3*prev_state+prev_selected_mcs,mcs1]/(A21[3*prev_state+prev_selected_mcs,mcs1]+A21[3*prev_state+prev_selected_mcs,mcs2+3]+A21[3*prev_state+prev_selected_mcs,mcs3+6]+A21[3*prev_state+prev_selected_mcs,mcs4+9])
        A21b = A21[3*prev_state+prev_selected_mcs,mcs2+3]/(A21[3*prev_state+prev_selected_mcs,mcs1]+A21[3*prev_state+prev_selected_mcs,mcs2+3]+A21[3*prev_state+prev_selected_mcs,mcs3+6]+A21[3*prev_state+prev_selected_mcs,mcs4+9])
        A21c = A21[3*prev_state+prev_selected_mcs,mcs3+6]/(A21[3*prev_state+prev_selected_mcs,mcs1]+A21[3*prev_state+prev_selected_mcs,mcs2+3]+A21[3*prev_state+prev_selected_mcs,mcs3+6]+A21[3*prev_state+prev_selected_mcs,mcs4+9])
        A21d = A21[3*prev_state+prev_selected_mcs,mcs4+9]/(A21[3*prev_state+prev_selected_mcs,mcs1]+A21[3*prev_state+prev_selected_mcs,mcs2+3]+A21[3*prev_state+prev_selected_mcs,mcs3+6]+A21[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A21a, A21b, A21c, A21d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability21 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward, "\nAlpha_A21 =",transition_probability21.state_probability(),"--->",end = "\n\n ")
                                  
                        
    elif slot_prev_state == 4 and slot_curr_state == 2:
        A22 = transition_probability22.state_probability()

        A22a = A22[3*prev_state+prev_selected_mcs,mcs1]/(A22[3*prev_state+prev_selected_mcs,mcs1]+A22[3*prev_state+prev_selected_mcs,mcs2+3]+A22[3*prev_state+prev_selected_mcs,mcs3+6]+A22[3*prev_state+prev_selected_mcs,mcs4+9])
        A22b = A22[3*prev_state+prev_selected_mcs,mcs2+3]/(A22[3*prev_state+prev_selected_mcs,mcs1]+A22[3*prev_state+prev_selected_mcs,mcs2+3]+A22[3*prev_state+prev_selected_mcs,mcs3+6]+A22[3*prev_state+prev_selected_mcs,mcs4+9])
        A22c = A22[3*prev_state+prev_selected_mcs,mcs3+6]/(A22[3*prev_state+prev_selected_mcs,mcs1]+A22[3*prev_state+prev_selected_mcs,mcs2+3]+A22[3*prev_state+prev_selected_mcs,mcs3+6]+A22[3*prev_state+prev_selected_mcs,mcs4+9])
        A22d = A22[3*prev_state+prev_selected_mcs,mcs4+9]/(A22[3*prev_state+prev_selected_mcs,mcs1]+A22[3*prev_state+prev_selected_mcs,mcs2+3]+A22[3*prev_state+prev_selected_mcs,mcs3+6]+A22[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A22a, A22b, A22c, A22d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability22 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward, "\nAlpha_A22 =",transition_probability22.state_probability(),"--->",end = "\n\n ")
                                 
                             
    elif slot_prev_state == 4 and slot_curr_state == 3:
        A23 = transition_probability23.state_probability()

        A23a = A23[3*prev_state+prev_selected_mcs,mcs1]/(A23[3*prev_state+prev_selected_mcs,mcs1]+A23[3*prev_state+prev_selected_mcs,mcs2+3]+A23[3*prev_state+prev_selected_mcs,mcs3+6]+A23[3*prev_state+prev_selected_mcs,mcs4+9])
        A23b = A23[3*prev_state+prev_selected_mcs,mcs2+3]/(A23[3*prev_state+prev_selected_mcs,mcs1]+A23[3*prev_state+prev_selected_mcs,mcs2+3]+A23[3*prev_state+prev_selected_mcs,mcs3+6]+A23[3*prev_state+prev_selected_mcs,mcs4+9])
        A23c = A23[3*prev_state+prev_selected_mcs,mcs3+6]/(A23[3*prev_state+prev_selected_mcs,mcs1]+A23[3*prev_state+prev_selected_mcs,mcs2+3]+A23[3*prev_state+prev_selected_mcs,mcs3+6]+A23[3*prev_state+prev_selected_mcs,mcs4+9])
        A23d = A23[3*prev_state+prev_selected_mcs,mcs4+9]/(A23[3*prev_state+prev_selected_mcs,mcs1]+A23[3*prev_state+prev_selected_mcs,mcs2+3]+A23[3*prev_state+prev_selected_mcs,mcs3+6]+A23[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A23a, A23b, A23c, A23d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability23 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward,"\nAlpha_A23 =",transition_probability23.state_probability(),"--->", end = "\n\n ")
                                  
                          
    elif slot_prev_state == 4 and slot_curr_state == 4:
        A24 = transition_probability24.state_probability()

        A24a = A24[3*prev_state+prev_selected_mcs,mcs1]/(A24[3*prev_state+prev_selected_mcs,mcs1]+A24[3*prev_state+prev_selected_mcs,mcs2+3]+A24[3*prev_state+prev_selected_mcs,mcs3+6]+A24[3*prev_state+prev_selected_mcs,mcs4+9])
        A24b = A24[3*prev_state+prev_selected_mcs,mcs2+3]/(A24[3*prev_state+prev_selected_mcs,mcs1]+A24[3*prev_state+prev_selected_mcs,mcs2+3]+A24[3*prev_state+prev_selected_mcs,mcs3+6]+A24[3*prev_state+prev_selected_mcs,mcs4+9])
        A24c = A24[3*prev_state+prev_selected_mcs,mcs3+6]/(A24[3*prev_state+prev_selected_mcs,mcs1]+A24[3*prev_state+prev_selected_mcs,mcs2+3]+A24[3*prev_state+prev_selected_mcs,mcs3+6]+A24[3*prev_state+prev_selected_mcs,mcs4+9])
        A24d = A24[3*prev_state+prev_selected_mcs,mcs4+9]/(A24[3*prev_state+prev_selected_mcs,mcs1]+A24[3*prev_state+prev_selected_mcs,mcs2+3]+A24[3*prev_state+prev_selected_mcs,mcs3+6]+A24[3*prev_state+prev_selected_mcs,mcs4+9])
          
        curr_state = np.random.choice([0, 1, 2, 3], p = [A24a, A24b, A24c, A24d])
        curr_selected_mcs = int(dataset.values[n, curr_state+5])
        ibler = float(dataset.values[n, curr_state])
        if ibler <= 0.1:
            reward = 1
        else:
            reward=0

        transition_probability24 = probability(prev_state,curr_state,reward,mcs1,mcs2,mcs3,mcs4,prev_selected_mcs,curr_selected_mcs)
        print(state[curr_state], ", reward =",reward, "\nAlpha_A24 =",transition_probability24.state_probability(),"--->", end = "\n\n ")
                                     
    prev_state = curr_state
    slot_prev_state = slot_curr_state
    prev_selected_mcs = curr_selected_mcs
    if reward == 1:
        total_reward = total_reward + 1
    else:
        total_penalty = total_penalty + 1
        
    sum_of_rewards = total_reward-total_penalty
    reward_array = np.append(reward_array, sum_of_rewards)
    steps_array = np.append(steps_array,n)

    
#final_rewards = transition_probability0.totalRewards()

plt.plot(steps_array, reward_array, color='red', marker='.')
plt.title('Average Sum of Rewards vs Time slots ', fontsize=14)
plt.xlabel('Time Slots', fontsize=12)
plt.ylabel('Average Sum of Rewards', fontsize=12)
plt.grid(True)
plt.show()
   
print("stop")
print("Sum of reward =",total_reward)
print("total penalty =",total_penalty)
#print("total rewards =",final_rewards)
print("Accuracy =",total_reward/(N-1))
print("Final_A0 = ",transition_probability0.state_probability())
print("Final_A1 = ",transition_probability1.state_probability())
print("Final_A2 = ",transition_probability2.state_probability())
print("Final_A3 = ",transition_probability3.state_probability())
print("Final_A4 = ",transition_probability4.state_probability())
print("Final_A5 = ",transition_probability5.state_probability())
print("Final_A6 = ",transition_probability6.state_probability())
print("Final_A7 = ",transition_probability7.state_probability())
print("Final_A8 = ",transition_probability8.state_probability())
print("Final_A9 = ",transition_probability9.state_probability())
print("Final_A10 = ",transition_probability10.state_probability())
print("Final_A11 = ",transition_probability11.state_probability())
print("Final_A12 = ",transition_probability12.state_probability())
print("Final_A13 = ",transition_probability13.state_probability())
print("Final_A14 = ",transition_probability14.state_probability())
print("Final_A15 = ",transition_probability15.state_probability())
print("Final_A16 = ",transition_probability16.state_probability())
print("Final_A17 = ",transition_probability17.state_probability())
print("Final_A18 = ",transition_probability18.state_probability())
print("Final_A19 = ",transition_probability19.state_probability())
print("Final_A20 = ",transition_probability20.state_probability())
print("Final_A21 = ",transition_probability21.state_probability())
print("Final_A22 = ",transition_probability22.state_probability())
print("Final_A23 = ",transition_probability23.state_probability())
print("Final_A24 = ",transition_probability24.state_probability())
# Out:
# eMBB User 2 --->
# Time slot = 1  , Slot 5 ,eMBB User 1 , reward = 0
# Alpha_A4 = [[1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [ 997 1000 1000 1000 1001 1000 1001 1000 1000 1000 1001 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]
#  [1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 1000]] --->
#
# Time slot = 2  , Slot 4 ,eMBB User 3 , reward = 1
# Alpha_A23 = [[1000  999 1000  999 1000 1000 1003 1000 1000  999 1000 1000]
# ...

# %%
plt.plot(steps_array, reward_array, color='red',  marker='.')
plt.title('Sum of Rewards vs Time slots ', fontsize=14)
plt.xlabel('Time Slots', fontsize=14)
plt.ylabel('Sum of Rewards', fontsize=14)
plt.grid(True)
plt.show()
plt.savefig('Desktop/reward_function.png')

# %%
def totalRewards(self):
        if self.reward == 1:
            total_reward = total_reward + 1
        else:
            total_penalty = total_penalty + 1
        
        return total_reward,total_penalty

# %%
import numpy as np
A0 = np.array([[1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
              [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
              [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12]])
mcs1 = 1
mcs2 = 2
mcs3 =3
mcs4 = 2
prev_selected_mcs = 2
prev_state = 0

# %%
import numpy as np
import scipy.linalg
import pandas as pd
A = np.array([[1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12],
             [1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12, 1/12]])

dataset = pd.read_csv('G:/UnderGraduate_Project\ibler and mcs2.csv')
prev_selected_mcs = 2
prev_state = 1
curr_state = 0
#mcs1=2
n=1
#for n in range (1,100):
#mcs1 = int(dataset.values[n, 5])
#mcs2 = int(dataset.values[n, 6])
#mcs3 = int(dataset.values[n, 7])
#mcs4 = int(dataset.values[n, 8])
#A3a =3*prev_state+prev_selected_mcs
#A3a = A[3*prev_state+prev_selected_mcs,2]
#A3a = A[3*prev_state+prev_selected_mcs,mcs1]
#print(mcs1)
#print(A[0,2])
#mcs1
#A3a = A[3*prev_state+prev_selected_mcs,mcs1]/(A[3*prev_state+prev_selected_mcs,mcs1]+A[3*prev_state+prev_selected_mcs,mcs2+3]+A[3*prev_state+prev_selected_mcs,mcs3+6]+A[3*prev_state+prev_selected_mcs,mcs4+9])
#print(A3a)
#ibler = float(dataset.values[n, curr_state])
ibler1 = dataset.values[n, curr_state]
#if ibler <= 0.1:
#    reward = 1
#else:
#    reward=0
#A
print(type(ibler1))
print(ibler1)
# Out:
# <class 'numpy.float64'>
# 0.1196

# %%
A0a = A0[3*prev_state+prev_selected_mcs,mcs1]/(A0[3*prev_state+prev_selected_mcs,mcs1]+A0[3*prev_state+prev_selected_mcs,mcs2]+A0[3*prev_state+prev_selected_mcs,mcs3]+A0[3*prev_state+prev_selected_mcs,mcs4])

# %%
A3[[0,0],[1,2]]
# Out:
# array([0.2  , 0.304])

# %%
A3[2]
# Out:
# array([0.242, 0.338, 0.202, 0.218])

# %%
A0a = A0[3*prev_state+prev_selected_mcs,mcs1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-9638b9d59d0c> in <module>
# ----> 1 A0a = A0[3*prev_state+prev_selected_mcs,mcs1]
#
# IndexError: index 5 is out of bounds for axis 0 with size 4

# %%
A0a
# Out:
# 0.25

# %%
import numpy as np
np_arr1 = 2
np_arr2 = np.array([[10, 20], [30, 40]])

np.append(np_arr1, np_arr2)
# Out:
# array([ 2, 10, 20, 30, 40])

# %%
if  A[3*self.prev_state+self.prev_selected_mcs, self.mcs1] > 0:
            A[3*self.prev_state + self.prev_selected_mcs, self.mcs1] = A[3*self.prev_state + self.prev_selected_mcs, self.mcs1]
        else:
            A[3*self.prev_state + self.prev_selected_mcs, self.mcs1] = 0
            
        print(type(A[3*self.prev_state + self.prev_selected_mcs,self.mcs1]))
        print(A[3*self.prev_state+self.prev_selected_mcs, 3*self.curr_state+self.curr_selected_mcs])
        z = A[3*self.prev_state + self.prev_selected_mcs,self.mcs2]
        print(z)
        if  z > 0:
            A[3*self.prev_state + self.prev_selected_mcs,3 + self.mcs2] = A[3*self.prev_state + self.prev_selected_mcs,3 + self.mcs2]
        else:
            A[3*self.prev_state + self.prev_selected_mcs,3 + self.mcs2] = 0
            
        if  A[3*self.prev_state + self.prev_selected_mcs, 6 + self.mcs3] > 0:
            A[3*self.prev_state + self.prev_selected_mcs, 6 + self.mcs3] = A[3*self.prev_state + self.prev_selected_mcs, 6 + self.mcs3]
        else:
            A[3*self.prev_state + self.prev_selected_mcs, 6 + self.mcs3] = 0
            
        if  A[3*self.prev_state + self.prev_selected_mcs, 9 + self.mcs4] > 0:
            A[3*self.prev_state + self.prev_selected_mcs, 9 + self.mcs4] = A[3*self.prev_state + self.prev_selected_mcs, 9 + self.mcs4]
        else:
            A[3*self.prev_state + self.prev_selected_mcs, 9 + self.mcs4] = 0
